# %%
# Import libraries
import pandas as pd
import trans as t
import os

# %%
# Get data
hist_path = "/Users/ombre/Documents/projects/R/directories_data_cleaning/data_to_share"
dict_path = "/Users/ombre/Documents/projects/R/directories_data_cleaning/data"

historical_data = pd.read_csv(os.path.join(hist_path, "test.csv"), 
                              sep = ";", 
                              error_bad_lines = False, 
                              encoding="latin")

practice_dict = pd.read_csv(os.path.join(dict_path, "practice_dictionary_final_mac.csv"),
                              sep = ";", 
                              error_bad_lines = False, 
                              encoding="latin")

regions_dict = pd.read_csv(os.path.join(dict_path, "dentons_regions.csv"),
                              sep = ";", 
                              error_bad_lines = False, 
                              encoding="latin")

# %%
# Chambers

# %%
# Legal 500

# %%
# Match practice

# %%
# Match region

# %%
# Additional columns

# %%
# Add historical data

dfs = [new_data, historical_data]
data_to_upload = pd.concat(dfs)

# %%
# Save

# %%
new_data = historical_data.tail(1000)

old = len(historical_data.index)
new = len(data_to_upload.index)
print(old-new)
# Out:
# -1000
